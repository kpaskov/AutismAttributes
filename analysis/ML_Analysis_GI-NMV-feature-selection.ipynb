# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from scipy import stats

# %% [markdown]
# # Preprocessing

# %%
# Read in dataset.
dataset = pd.read_csv('allSurveys-7-18-22-NMV-class-ASD-only-newSample.csv')

# Read in question mapping.
question_mapping_df = pd.read_csv('allSurveys-7-18-22-NMV-class-ASD-only-mapping.csv')

# %%
# Convert question mapping to dict.

question_mapping = {}
for index, row in question_mapping_df.iterrows():
  question_mapping['f' + str(row['fNumber'])] = str(row['fText'])

# %%
# Make sure dataset is balanced.
dataset['class'].value_counts()
# Out:
# 0    265
# 1    109
# Name: class, dtype: int64

# %%
# Basic preprocessing (convert everything into numbers).
processed_dataset = dataset.replace(to_replace=['male', 'female', 'other', 'yes', 'no'], value=[0, 1, -1, 1, 0])
processed_dataset
# Out:
#      childId  class  f1  f2  f3  f4  f5  f6  f7  f8  ...  f109  f110  f111  \
# 0         40      0  13   2   3   3   0   5   3   2  ...     4     4     4
# 1         58      0  19   2   3   4   4   5   4   5  ...     4     5     4
# 2         59      1  17   5   5   3   4   5   2   2  ...     3     5     5
# 3         60      0   9   4   3   4   4   4   3   3  ...     5     5     5
# 4        124      0  17   3   5   2   2   2   5   3  ...     2     0     4
# ..       ...    ...  ..  ..  ..  ..  ..  ..  ..  ..  ...   ...   ...   ...
# 369     8156      0   8   2   2   2   3   3   3   2  ...     5     4     5
# 370     8157      0   3   4   4   4   4   5   4   3  ...     5     5     5
# 371     8158      0   3   1   3   3   3   3   1   1  ...     3     5     5
# 372     8159      0  17   3   3   3   2   3   3   3  ...     1     4     3
# 373     8165      1   3   2   3   3   4   2   2   1  ...     4     4     4
#
#      f112  f113  f114  f115  f116  f117  f118
# 0       4     3     2     2     5     4     5
# 1       5     3     2     3     4     4     4
# 2       3     2     2     2     2     2     2
# 3       5     5     4     4     4     5     4
# 4       5     3     4     5     0     4     0
# ..    ...   ...   ...   ...   ...   ...   ...
# 369     5     5     4     4     5     4     4
# 370     5     5     1     2     5     3     5
# 371     4     1     2     2     3     2     3
# 372     1     1     3     2     2     2     3
# 373     0     4     2     2     3     3     3
#
# [374 rows x 120 columns]

# %%
# Balance dataset.

from sklearn.utils import resample

df_majority = processed_dataset[processed_dataset['class'] == 0]
df_minority = processed_dataset[processed_dataset['class'] == 1]

print(df_majority)

# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=265,    # to match majority class
                                 random_state=42)  # reproducible results

# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# Display new class counts
df_upsampled['class'].value_counts()
# Out:
#      childId  class  f1  f2  f3  f4  f5  f6  f7  f8  ...  f109  f110  f111  \
# 0         40      0  13   2   3   3   0   5   3   2  ...     4     4     4
# 1         58      0  19   2   3   4   4   5   4   5  ...     4     5     4
# 3         60      0   9   4   3   4   4   4   3   3  ...     5     5     5
# 4        124      0  17   3   5   2   2   2   5   3  ...     2     0     4
# 5        128      0   7   3   2   3   2   3   3   4  ...     5     5     4
# ..       ...    ...  ..  ..  ..  ..  ..  ..  ..  ..  ...   ...   ...   ...
# 368     8149      0   9   4   4   3   3   2   4   3  ...     5     5     5
# 369     8156      0   8   2   2   2   3   3   3   2  ...     5     4     5
# 370     8157      0   3   4   4   4   4   5   4   3  ...     5     5     5
# 371     8158      0   3   1   3   3   3   3   1   1  ...     3     5     5
# 372     8159      0  17   3   3   3   2   3   3   3  ...     1     4     3
#
#      f112  f113  f114  f115  f116  f117  f118
# 0       4     3     2     2     5     4     5
# 1       5     3     2     3     4     4     4
# 3       5     5     4     4     4     5     4
# 4       5     3     4     5     0     4     0
# 5       5     5     5     3     5     5     5
# ..    ...   ...   ...   ...   ...   ...   ...
# 368     5     5     3     3     5     5     5
# 369     5     5     4     4     5     4     4
# 370     5     5     1     2     5     3     5
# 371     4     1     2     2     3     2     3
# 372     1     1     3     2     2     2     3
#
# [265 rows x 120 columns]
# 0    265
# 1    265
# Name: class, dtype: int64

# %%
# Get X and y matrices for machine learning.

X_column_names = processed_dataset.columns.to_list()
X_column_names.remove('class')
X_column_names.remove('childId')
X = processed_dataset[X_column_names].values

y = processed_dataset['class'].values

# %%
# Baseline SVM classifier.

scoring = {'accuracy' : make_scorer(accuracy_score), 
           'precision' : make_scorer(precision_score),
           'recall' : make_scorer(recall_score), 
           'f1_score' : make_scorer(f1_score)}
      
clf = SVC()
cv_results = cross_validate(clf, X, y, cv=3, scoring=scoring)

print('Accuracy: ', stats.describe(cv_results['test_accuracy']))
print('Precision: ', stats.describe(cv_results['test_precision']))
print('Recall: ', stats.describe(cv_results['test_recall']))
print('F1 Score: ', stats.describe(cv_results['test_f1_score']))
# Out:
# Accuracy:  DescribeResult(nobs=3, minmax=(0.72, 0.7338709677419355), mean=0.7272903225806452, variance=4.847866805411058e-05, skewness=-0.18530497351766292, kurtosis=-1.499999999999995)
# Precision:  DescribeResult(nobs=3, minmax=(0.75, 1.0), mean=0.8333333333333334, variance=0.020833333333333336, skewness=0.7071067811865465, kurtosis=-1.500000000000001)
# Recall:  DescribeResult(nobs=3, minmax=(0.08108108108108109, 0.08333333333333333), mean=0.08258258258258257, variance=1.6908800692584338e-06, skewness=-0.7071067811865084, kurtosis=-1.5000000000000366)
# F1 Score:  DescribeResult(nobs=3, minmax=(0.14634146341463414, 0.15384615384615385), mean=0.15006253908692932, variance=1.4083027971281365e-05, skewness=0.03060693032775119, kurtosis=-1.4999999999999996)

# %% [markdown]
# # Tree-based Feature Selection and Predictive Model

# %%
# Tree-based feature selection.

clf = ExtraTreesClassifier(n_estimators=50)
clf = clf.fit(X, y)
feature_importances = clf.feature_importances_  

# Sort by most important features.
feature_and_importances = [(X_column_names[i], feature_importances[i]) for i in range(len(X_column_names))]
sorted_features_and_importances = sorted(feature_and_importances, key=lambda x: x[1], reverse=True)

# Print out most important features.
for x in sorted_features_and_importances:
  if x[0] in question_mapping:
    print(x[1], '=', question_mapping[x[0]])
  else:
    print(x[1], '=', x[0])

# print(sorted_features_and_importances)
# Out:
# 0.020742335106266937 = SCQ=Has childName ever had any objects (other than a soft toy or comfort blanket) that she/he had to carry around?
# 0.017307097521120245 = SSP=Has a weak grasp
# 0.017179254828104833 = SSP=Poor endurance/tires easily
# 0.017025496941819748 = SSP=Can't work with background noise (for example, fan, refrigerator)
# 0.01609955890713636 = SSP=Seems to have weak muscles
# 0.015374577692467244 = SCQ=Has childName ever got her/his pronouns mixed up (e.g., saying you or she/he for I)?
# 0.012565472091865672 = SSP=Can't lift heavy objects (for example, weak in comparison to same age children)
# 0.012241789838506014 = ASDQ=Become preoccupied with visual patterns or sounds? (for example, fascination with the way something looks or moves, excessive focus on certain sounds or videos)
# 0.012021724754788752 = SSP=Covers eyes or squints to protect eyes from light
# 0.011858957357147926 = SSP=Will only eat certain tastes
# 0.01180370870782059 = ASDQ=Flap or move their hands in an unusual way? (for example, the child claps or flaps their hands or flicks their fingers when they are excited)
# 0.011733655163789658 = SSP=Responds negatively to unexpected or loud noises (for example, cries or hides at noise from vacuum cleaner, dog barking, hair dryer)
# 0.011652248129495058 = SCQ=When she/he was 4 to 5, did childName ever spontaneously copy you (or other people) or what you were doing (such as vacuuming, gardening, or mending things)?
# 0.01156368230587459 = SSP=Doesn't seem to notice when face or hands are messy
# 0.01146766776817642 = SSP=Holds hands over ears to protect ears from sound
# 0.011153417596317529 = ASDQ=Show that relationships are important to them?
# 0.010983850228707613 = ASDQ=Read social cues? (facial expressions, gestures, body language)
# 0.010937606000731478 = ASDQ=Offer comfort to others when they are upset or sick?
# 0.010846604866319965 = SSP=Tires easily, especially when standing or holding particular body position
# 0.010822567350926479 = ASDQ=Repetitively play with objects or repeat actions without a purpose? (for example, lining up toys, spinning wheels, opening and closing doors, turning lights on and off, etc.)
# 0.010813401906696038 = SSP=Dislikes activities where head is upside down (for example, somersaults, roughhousing)
# 0.010776243546142435 = SSP=Expresses distress during grooming (for example, fights or cries during haircutting, face washing, fingernail cutting)
# 0.010747705943272498 = ASDQ=Engage with two or more close friends?
# 0.010735162573438692 = ASDQ=Repetitively jump, rock their body, spin in circles, or do other whole-body motions?
# 0.010536608533362354 = ASDQ=Seem too focused on an interest that is highly specific or narrow in scope?
# 0.010481074954312277 = ASDQ=Prefer to make lists, memorize facts, or learn about technical subjects?
# 0.010192401476274975 = SCQ=When she/he was 4 to 5, did childName ever spontaneously point at things around her/him just to show you things (not because she/he wanted them)?
# 0.010156304888256024 = SSP=Has difficulty standing in line or close to other people
# 0.009917535851530731 = SSP=Fears falling or heights
# 0.009913397030791497 = ASDQ=Have a back and forth conversation about another person’s interests and activities, not just their own?
# 0.009759518833180722 = SSP=Limits self to particular food textures/temperatures
# 0.00967664279083771 = ASDQ=Spend too much time on a game or subject that is not interesting to others?
# 0.009396403263938294 = ASDQ=Appear overly sensitive to loud noises?
# 0.009264022821273076 = SSP=Prefers long-sleeved clothing when it is warm or short sleeves when it is cold
# 0.009174735758250252 = SSP=Enjoys strange noises/seeks to make noise for noise's sake
# 0.009093165630570771 = SSP=Is distracted or has trouble functioning if there is a lot of noise around
# 0.009081756564704705 = ASDQ=Respond appropriately when others approach them? (for example, smiling, nodding, saying something back)
# 0.009071776608239743 = SCQ=Does she/he have any particular friends or a best friend?
# 0.009053481255205388 = SSP=Avoids going barefoot, especially in sand or grass
# 0.00905290108662237 = ASDQ=Insist on keeping a consistent daily schedule? (for example, gets upset with changes in the routine)
# 0.009032798452287997 = SCQ=When she/he was 4 to 5, did childName shake her/his head to mean no?
# 0.008979692096242454 = ASDQ=Engage in back and forth play with same-age peers? (for example, playing tag or cops-and-robbers by exchanging roles and allowing others to win OR in adolescents/adults playing turn-taking games or activities that require reciprocal give-and-take)
# 0.008961551612390298 = SSP=Reacts emotionally or aggressively to touch
# 0.008903348749468435 = SSP=Has difficulty paying attention
# 0.008898068736814094 = ASDQ=Communicate clearly so that other people know how they feel?
# 0.008855483408319898 = SSP=Rubs or scratches out a spot that has been touched
# 0.008788561683072967 = SCQ=When she/he was 4 to 5, when childName wanted something or wanted help, did she/he look at you and use gestures with sounds or words to get your attention?
# 0.008737088967039865 = ASDQ=Prefer to be with family or friends rather than alone?
# 0.008344892928648241 = SCQ=Has childName ever had any mannerisms or odd ways of moving her/his hands or fingers, such as flapping or moving her/his fingers in front of her/his eyes?
# 0.008293329149052845 = ASDQ=Seem overly fixated on one interest or activity?
# 0.00826535598918716 = SSP=Leaves clothing twisted on body
# 0.008190495667124651 = SSP=Has trouble completing tasks when the radio is on
# 0.008166020344947499 = ASDQ=Stand too close or show unexpected body language when interacting with others? (for example, a facial expression that doesn’t match what the child is saying or having their body turned away during conversation)
# 0.00815086065695789 = ASDQ=Have trouble changing their mind and being flexible?
# 0.008075437319154841 = SSP=Props to support self (even during activity)
# 0.008053816957793444 = SSP=Doesn't respond when name is called but you know the child's hearing is OK
# 0.008052616643114038 = SSP=Touches people and objects
# 0.008042062693630055 = ASDQ=Understand that expected behavior varies by social situation? (for example, behave differently at the library than at a party)
# 0.007916305751055484 = SCQ=When she/he was 4 to 5, did childName respond positively when another child approached her/him?
# 0.007879944251833882 = SCQ=Has childName ever used your hand like a tool or as if it were part of her/his own body (e.g., pointing with your finger, putting your hand on a doorknob to get you to open the door)?
# 0.007752522628559534 = SCQ=When she/he was 4 to 5, did childName ever show you things that interested her/him to engage your attention?
# 0.0076807651668261085 = SSP=Becomes overly excitable during movement activity
# 0.007655061555824731 = SCQ=Has childName ever had any interests that preoccupy her/him and might seem odd to other people (e.g., traffic lights, drainpipes, or timetables)?
# 0.007569917461967305 = familySurvey=age
# 0.007402825433296811 = SCQ=Has childName ever had any complicated movements of her/his whole body, such as spinning or repeatedly bouncing up and down?
# 0.007396619849380827 = SCQ=When she/he was 4 to 5, did childName usually look at you directly in the face when doing things with you or talking with you?
# 0.007390007207907601 = SCQ=When she/he was 4 to 5, did childName ever try to comfort you if you were sad or hurt?
# 0.007376188389673398 = SCQ=When she/he was 4 to 5, did childName ever offer to share things other than food with you?
# 0.007360135880964174 = ASDQ=Dislike certain lights, sounds, textures, foods, or smells?
# 0.007316412240810613 = ASDQ=Appear fascinated by sensory experiences? (for example, staring at lights, fans, running water, symmetrical patterns, street signs, falling or dangling objects, textures, smells, etc.)
# 0.007306152989344681 = ASDQ=Seek out playful interactions, playmates, or friendships?
# 0.007276945421009464 = ASDQ=Repeat sounds, words, or lines from videos?
# 0.007246934639571906 = SSP=Picky eater, especially regarding food textures
# 0.007234780481656708 = SCQ=When she/he was 4 to 5, did childName nod her/his head to mean yes?
# 0.007234545279834153 = SSP=Withdraws from splashing water
# 0.007179598043044561 = ASDQ=Start interactions with others without prompting?
# 0.007133161922540933 = SCQ=Has childName ever injured her/himself deliberately, such as by biting her/his arm or banging her/his head?
# 0.007117320234304091 = SSP=Is bothered by bright lights after others have adapted to the light
# 0.007048391645764889 = ASDQ=Share enjoyment about interests or activities with other people?
# 0.007021270543868019 = ASDQ=Take things too literally? (for example, not understanding when people are sarcastic, joking, or using figures of speech such as “It’s raining cats and dogs!” Or “A leopard can’t change his spots!”)
# 0.006991193281879439 = SSP=Seeks all kinds of movement and this interferes with daily routines (for example, can't sit still, fidgets)
# 0.006937809829652572 = SCQ=When she/he was 4 to 5, did childName show a normal range of facial expressions?
# 0.006924555047610087 = SSP=Becomes anxious or distressed when feet leave the ground
# 0.006875757118432795 = SSP=Avoids certain tastes or food smells that are typically part of children's diets
# 0.006862069516589745 = ASDQ=Try to be physically and emotionally-connected to family and friends?
# 0.006780516661403137 = SCQ=Has childName ever used words that she/he seemed to have invented or made up her/himself; put things in odd, indirect ways; or used metaphorical ways of saying things (e.g., saying “hot rain” for “steam”)?
# 0.0067076776245303575 = SSP=Appears to not hear what you say (for example, does not tune-in to what you say)
# 0.006676214745179873 = SCQ=Has childName ever seemed to be unusually interested in the sight, feel, sound, taste, or smell of things or people?
# 0.0065309409410028675 = SSP=Watches everyone when they move around the room
# 0.006371306395820685 = SCQ=Can you have a to and fro “conversation” with childName that involves taking turns or building on what you have said?
# 0.00633304071436374 = ASDQ=Use gestures to communicate? (for example, wave, point, nod, shake head)
# 0.00633047213578972 = SCQ=When she/he was 4 to 5, did childName seem interested in other children of approximately the same age whom she/he did not know?
# 0.006289798274276718 = SCQ=When she/he was 4 to 5, did childName smile back if someone smiled at her/him?
# 0.006276793665027429 = ASDQ=Speak with an unusual volume, tone, rhythm, or rate of speech?
# 0.0062522903060777 = ASDQ=Prefer to engage with specific parts of objects rather than the whole object? (for example, parts of a toy, small pieces of a game, or parts of electrical equipment)
# 0.0061517733656325435 = SCQ=When she/he was 4 to 5, did childName ever seem to want you to join in her/his enjoyment of something?
# 0.0060597059224687996 = ASDQ=Think or talk about the same topic over and over?
# 0.0060577240197148075 = ASDQ=Have difficulty transitioning from one activity to another?
# 0.006033618096609996 = SCQ=When she/he was 4 to 5, did childName ever spontaneously join in and try to copy the actions in social games, such as The Mulberry Bush or London Bridge is Falling Down?
# 0.00603209860076144 = ASDQ=Want to follow strict rules, rituals, or sequences? (for example, taking the same route to a destination, touching things in a certain sequence, eating foods in a certain order, playing a game a certain way, or performing activities until they are “just right”)
# 0.0060096905374805755 = SCQ=When she/he was 4 to 5, did childName ever play imaginative games with another child in such a way that you could tell that they each understood what the other was pretending?
# 0.006007294039731391 = SCQ=When she/he was 4 to 5, did childName play any pretend or make-believe games?
# 0.005948909638407945 = SCQ=When she/he was 4 to 5 (or if less than 4, in the past 12 months), did childName ever talk with you just to be friendly (rather than to get something)?
# 0.005857201422094663 = ASDQ=Get upset in crowded or busy places?
# 0.005803287755250738 = ASDQ=Make expected eye contact? (not too brief, too intense, or looking past people)
# 0.005756724781815061 = SCQ=When she/he was 4 to 5, did childName play cooperatively in games that required joining in with a group of other children, such as hide-and-seek or ball games?
# 0.005705994725663676 = SSP=Jumps from one activity to another so that it interferes with play
# 0.005668459541825429 = SCQ=Has childName ever used odd phrases or said the same thing over and over in almost exactly the same way (either phrases that she/he has heard other people use or ones that she/he has made up)?
# 0.005573864654132715 = SCQ=Has childName ever said the same thing over and over in exactly the same way or insisted that you say the same thing over and over again?
# 0.005524192707193056 = SCQ=When she/he was 4 to 5, if you came into a room and started talking to her/him without calling her/his name, did she/he usually look up and pay attention to you?
# 0.0054622336283766375 = SCQ=Has childName ever seemed to be more interested in parts of a toy or an object (e.g., spinning the wheels of a car), rather than using the object as it was intended?
# 0.005424721484234813 = SCQ=Has childName ever used socially inappropriate questions or statements? (For example, has she/he ever regularly asked personal questions or made personal comments at awkward times?)
# 0.005086229796916844 = SCQ=Has childName ever had things that she/he seemed to have to do in a very particular way or order or rituals that she/he insisted that you go through?
# 0.004254936277648591 = SCQ=Has childName ever had any special interests that were unusual in their intensity but otherwise appropriate for her/his age and peer group (e.g., trains, dinosaurs)?
# 0.003963683582173657 = SCQ=Has childName’s facial expression usually seemed appropriate to the particular situation, as far as you could tell?
# 0.0038873476540727397 = SCQ=When she/he was 4 to 5, did childName ever use gestures, other than pointing or pulling your hand, to let you know what she/he wanted?
# 0.003744000000409508 = ASDQ=Seem to understand what others are thinking or feeling?
# 0.0032830679611774607 = SCQ=Is childName now able to talk using short phrases or sentences? If no, skip to question 8.

# %%
# Train SVM with top-5 features.
# sorted_features_and_importances
# X = processed_dataset[['q33', 'q11', 'q21', 'q9', 'q4']].values
# y = processed_dataset['ASD'].values

# scoring = {'accuracy' : make_scorer(accuracy_score), 
#            'precision' : make_scorer(precision_score),
#            'recall' : make_scorer(recall_score), 
#            'f1_score' : make_scorer(f1_score)}
      
# clf = SVC()
# cv_results = cross_validate(clf, X, y, cv=3, scoring=scoring)

# print('Accuracy: ', stats.describe(cv_results['test_accuracy']))
# print('Precision: ', stats.describe(cv_results['test_precision']))
# print('Recall: ', stats.describe(cv_results['test_recall']))
# print('F1 Score: ', stats.describe(cv_results['test_f1_score']))

# %% [markdown]
# # Recursive Feature Elimination-based Feature Selection and Predictive Model

# %%
# RFE-based feature selection.

estimator = SVR(kernel="linear")
selector = RFE(estimator, n_features_to_select=5, step=1)
selector = selector.fit(X, y)
selector.support_, selector.ranking_

# Get selected features.
selected_features = []
for i in range(len(selector.support_)):
  if selector.support_[i] == True:
    selected_features.append(X_column_names[i])

# Print out most important features.
for feat in selected_features:
  if feat in question_mapping:
    print(question_mapping[feat])
  else:
    print(feat)

selected_features
# Out:
# ASDQ=Communicate clearly so that other people know how they feel?
# SCQ=Has childName ever got her/his pronouns mixed up (e.g., saying you or she/he for I)?
# SCQ=Has childName ever had any objects (other than a soft toy or comfort blanket) that she/he had to carry around?
# SCQ=When she/he was 4 to 5, did childName ever spontaneously point at things around her/him just to show you things (not because she/he wanted them)?
# SCQ=When she/he was 4 to 5, did childName ever offer to share things other than food with you?
# ['f7', 'f45', 'f58', 'f62', 'f69']

# %%
# Train SVM with top-5 features.
# sorted_features_and_importances
# X = processed_dataset[['q9', 'q11', 'q19', 'q22', 'q33']].values
# y = processed_dataset['ASD'].values

# scoring = {'accuracy' : make_scorer(accuracy_score), 
#            'precision' : make_scorer(precision_score),
#            'recall' : make_scorer(recall_score), 
#            'f1_score' : make_scorer(f1_score)}
      
# clf = SVC()
# cv_results = cross_validate(clf, X, y, cv=3, scoring=scoring)

# print('Accuracy: ', stats.describe(cv_results['test_accuracy']))
# print('Precision: ', stats.describe(cv_results['test_precision']))
# print('Recall: ', stats.describe(cv_results['test_recall']))
# print('F1 Score: ', stats.describe(cv_results['test_f1_score']))
